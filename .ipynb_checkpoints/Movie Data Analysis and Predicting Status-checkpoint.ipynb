# %%
# !pip install squarify
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting squarify
#   Obtaining dependency information for squarify from https://files.pythonhosted.org/packages/0b/2b/2e77c35326efec19819cd1d729540d4d235e6c2a3f37658288a363a67da5/squarify-0.4.3-py3-none-any.whl.metadata
#   Downloading squarify-0.4.3-py3-none-any.whl.metadata (540 bytes)
# Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 23.3 will enforce this behaviour change. A possible replacement is to use pip for package installation..

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import squarify
from collections import defaultdict,Counter
from sklearn.model_selection import train_test_split as tts
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("movie_metadata.csv")

# %%
df.sample(5)
# Out:
#                  color    director_name  num_critic_for_reviews  duration  \
# 4917   Black and White     James Kerwin                    25.0      89.0
# 1090             Color    Thomas Carter                   127.0     136.0
# 283              Color     Ridley Scott                   265.0     171.0
# 5039             Color              NaN                    43.0      43.0
# 2549             Color  Cyrus Nowrasteh                    24.0     111.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 4917                      0.0                    31.0  Chase Masterson
# 1090                     49.0                   730.0    Rick Gonzalez
# 283                       0.0                   695.0   Connie Nielsen
# 5039                      NaN                   319.0    Valorie Curry
# 2549                     19.0                   107.0    Vincent Walsh
#
#       actor_1_facebook_likes        gross                              genres  \
# 4917                   236.0          NaN  Drama|Music|Mystery|Romance|Sci-Fi
# 1090                 17000.0   67253092.0                         Drama|Sport
# 283                   3000.0  187670866.0                Action|Drama|Romance
# 5039                   841.0          NaN        Crime|Drama|Mystery|Thriller
# 2549                   241.0    6462576.0                               Drama
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 4917  ...                 10.0  English      USA              PG    2500000.0
# 1090  ...                209.0  English      USA           PG-13   30000000.0
# 283   ...               2368.0  English      USA               R  103000000.0
# 5039  ...                359.0  English      USA           TV-14          NaN
# 2549  ...                 30.0  English      USA           PG-13   18500000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 4917      2008.0                  189.0        5.4          1.78
# 1090      2005.0                  807.0        7.2          2.35
# 283       2000.0                  933.0        8.5          2.35
# 5039         NaN                  593.0        7.5         16.00
# 2549      2016.0                  118.0        5.4          2.35
#
#      movie_facebook_likes
# 4917                   83
# 1090                    0
# 283                 21000
# 5039                32000
# 2549                    0
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.shape
# Out:
# (5043, 28)

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
df['gross'].fillna(df['gross'].median(),inplace=True)
df['budget'].fillna(df['budget'].median(),inplace=True)
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (4411, 28)

# %% [markdown]
# ## About the Data (EDA)

# %% [markdown]
# ### Creating a new column to show main genre of movie. This will help in sorting out movies according to their genre types

# %%
summary_stats = df.describe()

# Display the summary statistics
print(summary_stats)
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4409.000000  4409.000000              4409.000000
# mean               155.096847   109.355863               757.508959
# std                120.743099    22.381705              2954.169039
# min                  1.000000    20.000000                 0.000000
# 25%                 66.000000    95.000000                10.000000
# 50%                125.000000   105.000000                57.000000
# 75%                211.000000   119.000000               221.000000
# max                813.000000   330.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4409.000000             4409.000000  4.409000e+03
# mean               701.687684             7113.826718  4.798048e+07
# std               1766.600120            14843.701640  6.609049e+07
# min                  0.000000                0.000000  1.620000e+02
# 25%                163.000000              687.000000  8.596914e+06
# 50%                402.000000             1000.000000  2.551750e+07
# 75%                658.000000            12000.000000  5.825529e+07
# max              23000.000000           640000.000000  7.605058e+08
#
#        num_voted_users  cast_total_facebook_likes  facenumber_in_poster  \
# count     4.409000e+03                4409.000000           4409.000000
# mean      9.437038e+04               10550.764799              1.352914
# std       1.444397e+05               18233.620879              2.000616
# min       2.800000e+01                   0.000000              0.000000
# 25%       1.442900e+04                1653.000000              0.000000
# 50%       4.410300e+04                3535.000000              1.000000
# 75%       1.104860e+05               15046.000000              2.000000
# max       1.689764e+06              656730.000000             43.000000
#
#        num_user_for_reviews        budget   title_year  \
# count           4409.000000  4.409000e+03  4409.000000
# mean             305.003629  4.137305e+07  2001.770469
# std              391.335694  2.089689e+08    12.414277
# min                1.000000  2.180000e+02  1927.000000
# 25%               90.000000  9.000000e+06  1998.000000
# 50%              184.000000  2.000000e+07  2005.000000
# 75%              363.000000  4.500000e+07  2010.000000
# max             5060.000000  1.221550e+10  2016.000000
#
#        actor_2_facebook_likes   imdb_score  aspect_ratio  \
# count             4409.000000  4409.000000   4409.000000
# mean              1820.207076     6.459991      2.105765
# std               4265.429799     1.079360      0.504484
# min                  0.000000     1.600000      1.180000
# 25%                330.000000     5.900000      1.850000
# 50%                641.000000     6.600000      2.350000
# 75%                947.000000     7.200000      2.350000
# max             137000.000000     9.300000     16.000000
#
#        movie_facebook_likes   num_genres
# count           4409.000000  4409.000000
# mean            8357.842368     2.942844
# std            20263.181025     1.179798
# min                0.000000     1.000000
# 25%                0.000000     2.000000
# 50%              196.000000     3.000000
# 75%            10000.000000     4.000000
# max           349000.000000     8.000000

# %%
genre_counts = df['main_genre'].value_counts()
# Plot a pie chart
plt.figure(figsize=(5, 4))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Movie Genres')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
df['main_genre'] = df['genres'].apply(lambda x: x.split('|')[0] if '|' in x else x)

# %%
df.sample(2)
# Out:
#      color       director_name  num_critic_for_reviews  duration  \
# 383  Color      Brian De Palma                   181.0     114.0
# 763  Color  Jean-Pierre Jeunet                   223.0     116.0
#
#      director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 383                      0.0                   281.0   Connie Nielsen
# 763                      0.0                   672.0  Michael Wincott
#
#      actor_1_facebook_likes       gross                     genres  ...  \
# 383                  3000.0  60874615.0  Adventure|Sci-Fi|Thriller  ...
# 763                  1000.0  47748610.0       Action|Horror|Sci-Fi  ...
#
#     language country  content_rating      budget title_year  \
# 383  English     USA              PG  90000000.0     2000.0
# 763  English     USA               R  75000000.0     1997.0
#
#      actor_2_facebook_likes imdb_score aspect_ratio  movie_facebook_likes  \
# 383                   933.0        5.6         2.35                     0
# 763                   720.0        6.3         2.35                     0
#
#     main_genre
# 383  Adventure
# 763     Action
#
# [2 rows x 29 columns]

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='imdb_score',y='main_genre',data=df)
plt.title('Movie Genres with their imdb scores',fontsize=18)
plt.show()

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
z_scores = np.abs((df[numeric_cols] - df[numeric_cols].mean()) / df[numeric_cols].std())
threshold = 3
df = df[(z_scores < threshold).all(axis=1)]

# %%
df.shape
# Out:
# (3630, 29)

# %%
df.title_year.value_counts(dropna=True).sort_index().plot(kind='barh',figsize=(15,20))
plt.title("Number of Movies released every year",fontsize=18)
plt.show()

# %%
df.main_genre.value_counts(dropna=True).sort_values().plot(kind='barh',figsize=(7,))
plt.title("Number of Movies released every year",fontsize=12)
plt.show()

# %%
plt.figure(figsize=(15, 10))
squarify.plot(Counter(df['main_genre']).values(),label=Counter(df['main_genre']).keys(),text_kwargs={'fontsize':12}
             ,bar_kwargs={'alpha':.7},pad=True)
plt.title("Genres",fontsize=18)
plt.axis("off")
plt.show()

# %%
# Movies with the lowest Imdb rating 
df[df['imdb_score']==3.3]
# Out:
#       color        director_name  num_critic_for_reviews  duration  \
# 313   Color                Pitof                   212.0      87.0
# 1303  Color       William Malone                   104.0     101.0
# 1934  Color           Bob Spiers                    33.0      93.0
# 2519  Color     Ian Iqbal Rashid                    62.0      94.0
# 2550  Color  Perry Andelin Blake                    56.0      80.0
# 2935  Color          Tamra Davis                   111.0      93.0
# 3197  Color            Tom Brady                    49.0      97.0
# 3230  Color          Alan Metter                    17.0      83.0
# 3799  Color         Klaus Menzel                    13.0     103.0
# 4005  Color  Anthony C. Ferrante                   139.0      97.0
# 4019  Color             Uwe Boll                    17.0      86.0
# 4127  Color   Philip Zlotorynski                    14.0      80.0
# 4285  Color          Gary Rogers                     7.0     120.0
# 4769  Color          Tamra Davis                   111.0      93.0
#
#       director_facebook_likes  actor_3_facebook_likes           actor_2_name  \
# 313                      26.0                   566.0  Christopher Heyerdahl
# 1303                     37.0                   595.0          Jeffrey Combs
# 1934                     14.0                   199.0         Richard Briers
# 2519                      8.0                    66.0            Clé Bennett
# 2550                     11.0                   499.0         Kenan Thompson
# 2935                     33.0                   135.0      Katherine Boecher
# 3197                    105.0                   269.0           Kevin Nealon
# 3230                      3.0                   421.0        Michael Winslow
# 3799                     34.0                   227.0      Jacqueline Bisset
# 4005                     48.0                   689.0             John Heard
# 4019                    892.0                    50.0           Shelly Varod
# 4127                      0.0                    19.0    Darren Keefe Reiher
# 4285                      0.0                    40.0         Kirby Heyborne
# 4769                     33.0                   135.0      Katherine Boecher
#
#       actor_1_facebook_likes       gross  \
# 313                    827.0  40198710.0
# 1303                  2000.0  13208023.0
# 1934                  1000.0  29247405.0
# 2519                   328.0   7070459.0
# 2550                   911.0  40363530.0
# 2935                  1000.0  37188667.0
# 3197                   982.0   2331318.0
# 3230                 16000.0    126247.0
# 3799                   811.0     16066.0
# 4005                   984.0  25517500.0
# 4019                   603.0  25517500.0
# 4127                   231.0  25517500.0
# 4285                   178.0   1098224.0
# 4769                  1000.0  37188667.0
#
#                                      genres  ...  country content_rating  \
# 313   Action|Crime|Fantasy|Romance|Thriller  ...      USA          PG-13
# 1303                  Crime|Horror|Thriller  ...       UK              R
# 1934                    Comedy|Family|Music  ...       UK             PG
# 2519                                  Drama  ...   Canada          PG-13
# 2550                          Comedy|Family  ...      USA             PG
# 2935                           Comedy|Drama  ...      USA          PG-13
# 3197                                 Comedy  ...      USA              R
# 3230                           Comedy|Crime  ...      USA             PG
# 3799               Mystery|Romance|Thriller  ...  Germany              R
# 4005                                 Horror  ...      USA          TV-14
# 4019      Action|Adventure|Fantasy|Thriller  ...   Canada              R
# 4127                                 Comedy  ...      USA              R
# 4285                              Adventure  ...      USA          PG-13
# 4769                           Comedy|Drama  ...      USA          PG-13
#
#            budget  title_year actor_2_facebook_likes  imdb_score aspect_ratio  \
# 313   100000000.0      2004.0                  825.0         3.3         2.35
# 1303   42000000.0      2002.0                  886.0         3.3         2.35
# 1934   25000000.0      1997.0                  401.0         3.3         1.85
# 2519   20000000.0      2007.0                  122.0         3.3         1.85
# 2550   16000000.0      2002.0                  521.0         3.3         1.85
# 2935   12000000.0      2002.0                  188.0         3.3         1.85
# 3197   10000000.0      2011.0                  503.0         3.3         1.85
# 3230    6200000.0      1994.0                  542.0         3.3         1.85
# 3799    5000000.0      2004.0                  522.0         3.3         2.35
# 4005    1000000.0      2013.0                  697.0         3.3         1.78
# 4019    3500000.0      2014.0                  145.0         3.3         1.78
# 4127    3000000.0      2005.0                   27.0         3.3         1.78
# 4285    2000000.0      2003.0                   69.0         3.3         1.85
# 4769   12000000.0      2002.0                  188.0         3.3         1.85
#
#      movie_facebook_likes  main_genre num_genres
# 313                     0      Action          5
# 1303                  612       Crime          3
# 1934                    0      Comedy          3
# 2519                  238       Drama          1
# 2550                 1000      Comedy          2
# 2935                    0      Comedy          2
# 3197                    0      Comedy          1
# 3230                  321      Comedy          2
# 3799                   40     Mystery          3
# 4005                93000      Horror          1
# 4019                  721      Action          4
# 4127                   48      Comedy          1
# 4285                   32   Adventure          1
# 4769                    0      Comedy          2
#
# [14 rows x 30 columns]

# %%
# Movie with the highest Imdb rating
df[df['imdb_score']==8.9]
# Out:
#                  color      director_name  num_critic_for_reviews  duration  \
# 339              Color      Peter Jackson                   328.0     192.0
# 1874   Black and White   Steven Spielberg                   174.0     185.0
# 3355             Color  Quentin Tarantino                   215.0     178.0
# 4498             Color       Sergio Leone                   181.0     142.0
# 4822   Black and White       Sidney Lumet                   177.0      96.0
#
#       director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 339                       0.0                   416.0      Billy Boyd
# 1874                  14000.0                   212.0  Embeth Davidtz
# 3355                  16000.0                   857.0     Eric Stoltz
# 4498                      0.0                    24.0  Luigi Pistilli
# 4822                      0.0                   253.0     Lee J. Cobb
#
#       actor_1_facebook_likes        gross                          genres  \
# 339                   5000.0  377019252.0  Action|Adventure|Drama|Fantasy
# 1874                 14000.0   96067179.0         Biography|Drama|History
# 3355                 13000.0  107930000.0                     Crime|Drama
# 4498                 16000.0    6100000.0                         Western
# 4822                   359.0   25517500.0                     Crime|Drama
#
#       ... country content_rating      budget  title_year  \
# 339   ...     USA          PG-13  94000000.0      2003.0
# 1874  ...     USA              R  22000000.0      1993.0
# 3355  ...     USA              R   8000000.0      1994.0
# 4498  ...   Italy       Approved   1200000.0      1966.0
# 4822  ...     USA      Not Rated    350000.0      1957.0
#
#      actor_2_facebook_likes  imdb_score aspect_ratio movie_facebook_likes  \
# 339                   857.0         8.9         2.35                16000
# 1874                  795.0         8.9         1.85                41000
# 3355                  902.0         8.9         2.35                45000
# 4498                   34.0         8.9         2.35                20000
# 4822                  259.0         8.9         1.66                40000
#
#       main_genre num_genres
# 339       Action          4
# 1874   Biography          3
# 3355       Crime          2
# 4498     Western          1
# 4822       Crime          2
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Histogram of all columns in df

# %%
df.hist(bins=30,figsize=(15,15),color='g')
plt.show()

# %% [markdown]
# ## Adding New Column that shows number of genres in movie

# %%
df['num_genres'] = df.genres.apply(lambda x: len(x.split('|')))

# %%
df.sample(2)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 3388  Color  Nicole Holofcener                   231.0      93.0
# 2187  Color        Mennan Yapo                   184.0      96.0
#
#       director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 3388                    132.0                   216.0     Ben Falcone
# 2187                      9.0                   107.0  Amber Valletta
#
#       actor_1_facebook_likes       gross                  genres  ... country  \
# 3388                   434.0  17536788.0    Comedy|Drama|Romance  ...     USA
# 2187                   826.0  47852604.0  Drama|Mystery|Thriller  ...     USA
#
#      content_rating      budget  title_year actor_2_facebook_likes  \
# 3388          PG-13   8000000.0      2013.0                  265.0
# 2187          PG-13  20000000.0      2007.0                  626.0
#
#       imdb_score aspect_ratio movie_facebook_likes  main_genre num_genres
# 3388         7.1         1.85                12000      Comedy          3
# 2187         5.9         2.35                    0       Drama          3
#
# [2 rows x 30 columns]

# %%
df.num_genres.max()
# Out:
# 8

# %%
df[df.num_genres==8]
# Out:
#       color       director_name  num_critic_for_reviews  duration  \
# 902   Color           Don Bluth                    78.0      94.0
# 1387  Color  John Frankenheimer                   126.0     124.0
# 2340  Color        Kevin Munroe                   138.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes    actor_2_name  \
# 902                     383.0                   753.0  Kelsey Grammer
# 1387                    287.0                   475.0     James Frain
# 2340                     14.0                   311.0   Laura Spencer
#
#       actor_1_facebook_likes       gross  \
# 902                   4000.0  58297830.0
# 1387                  9000.0  23360779.0
# 2340                   403.0   1183354.0
#
#                                                  genres  ... country  \
# 902   Adventure|Animation|Drama|Family|Fantasy|Music...  ...     USA
# 1387  Action|Adventure|Crime|Drama|Family|Fantasy|Ro...  ...     USA
# 2340  Action|Comedy|Crime|Fantasy|Horror|Mystery|Sci...  ...     USA
#
#      content_rating      budget  title_year actor_2_facebook_likes  \
# 902               G  50000000.0      1997.0                  808.0
# 1387              R  34000000.0      2000.0                 1000.0
# 2340          PG-13  20000000.0      2010.0                  368.0
#
#       imdb_score aspect_ratio movie_facebook_likes  main_genre num_genres
# 902          7.1         2.35                    0   Adventure          8
# 1387         5.7         2.35                  852      Action          8
# 2340         5.1         2.35                    0      Action          8
#
# [3 rows x 30 columns]

# %%
numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(12, 10))
sns.heatmap(numeric_df.corr(), annot=True, linewidths=.5, cmap='coolwarm', square=True, cbar_kws={'label': 'Correlation Coefficient'})
plt.title("Correlation plot", fontsize=18)
plt.show()

# %% [markdown]
# ### Selected Cols for model
# num_critic_for_reviews<br>
# duration<br>
# num_voted_users<br>
# num_user_for_reviews<br>
# movie_facbook_likes<br>
# director_facebook_likes<br>

# %%
X = df[['num_critic_for_reviews','duration','num_voted_users','num_user_for_reviews','movie_facebook_likes'
       ,'director_facebook_likes']]
y = df['imdb_score']

# %%
X.shape,y.shape
# Out:
# ((3630, 6), (3630,))

# %%
X_train, X_test, y_train, y_test = tts(X,y,test_size=0.2,random_state=32)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
pred_lm= lm.predict(X_test)
print("Mean squared error using linear regression",mean_squared_error(y_test,pred_lm))
print("Mean absolute error using linear regression",mean_absolute_error(y_test,pred_lm))
# Out:
# Mean squared error using linear regression 0.7164616789200854
# Mean absolute error using linear regression 0.6674037063372618

# %%
dtc = DecisionTreeRegressor()
dtc.fit(X_train, y_train)
pred_dt = dtc.predict(X_test)
print("Mean squared error using Decision Tree Regression",mean_squared_error(y_test,pred_dt))
print("Mean absolute error using Decision Tree regression",mean_absolute_error(y_test,pred_dt))
# Out:
# Mean squared error using Decision Tree Regression 1.334077134986226
# Mean absolute error using Decision Tree regression 0.88732782369146

# %%
svr = SVR(kernel='rbf')
svr.fit(X_train,y_train)
pred_svr = svr.predict(X_test)
print("Mean squared error using Support Vector regression",mean_squared_error(y_test,pred_svr))
print("Mean absolute error using Support Vector regression",mean_absolute_error(y_test,pred_svr))
# Out:
# Mean squared error using Support Vector regression 0.7897038097630096
# Mean absolute error using Support Vector regression 0.6988435995927077

# %%
knn = KNeighborsRegressor(n_neighbors=12)
knn.fit(X_train,y_train)
pred_knn = knn.predict(X_test)
print("Mean squared error using KNN regression",mean_squared_error(y_test,pred_knn))
print("Mean absolute error using KNN regression",mean_absolute_error(y_test,pred_knn))
# Out:
# Mean squared error using KNN regression 0.8213567493112947
# Mean absolute error using KNN regression 0.7115472910927455

# %% [markdown]
# ### Conclusion:
# #### Linear Regression model seems to perform best among all with MSE = 0.67 and MAE = 0.65

# %% [markdown]
# ## To work with Classification models, Adding another column "movie_status" that contains wether movie is hit or (flop or average)

# %%
def getStatus(row):
    bgt = row['budget']
    grs = row['gross']
    
    if bgt*3<=grs:
        return 1
    return 0

# %%
df['movie_status'] = df[['budget','gross']].apply(getStatus, axis=1) #1 means HIT, 0 means FLOP

# %%
df['movie_status']
# Out:
# 5       0
# 7       0
# 12      0
# 14      0
# 16      0
#        ..
# 5026    1
# 5027    1
# 5033    1
# 5035    1
# 5042    1
# Name: movie_status, Length: 3630, dtype: int64

# %%
y = df['movie_status']
X = df[['num_critic_for_reviews','duration','num_voted_users','num_user_for_reviews','movie_facebook_likes'
       ,'director_facebook_likes']]

# %%
X_train, X_test, y_train, y_test = tts(X,y,test_size=0.2,random_state=32)

# %%
svc = SVC(kernel='rbf')
svc.fit(X_train,y_train)
pred_svc = svc.predict(X_test)
print("Classification Report for Suppprt Vector Classifier:\n", classification_report(y_test, pred_svc))
accuracy = accuracy_score(y_test, pred_svc)
print("Accuracy score for Support Vector Classifier: ", accuracy)
# Out:
# Classification Report for Suppprt Vector Classifier:
#                precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90       589
#            1       0.00      0.00      0.00       137
#
#     accuracy                           0.81       726
#    macro avg       0.41      0.50      0.45       726
# weighted avg       0.66      0.81      0.73       726
#
# Accuracy score for Support Vector Classifier:  0.8112947658402204
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train, y_train)
pred_knn_cls = knn.predict(X_test)
print("Classification Report for KNN Classifier:\n", classification_report(y_test, pred_knn_cls))
accuracy = accuracy_score(y_test, pred_knn_cls)
print("Accuracy score for KNN Classifier: ", accuracy)
# Out:
# Classification Report for KNN Classifier:
#                precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90       589
#            1       1.00      0.01      0.01       137
#
#     accuracy                           0.81       726
#    macro avg       0.91      0.50      0.46       726
# weighted avg       0.85      0.81      0.73       726
#
# Accuracy score for KNN Classifier:  0.8126721763085399

# %%
dt_cls = DecisionTreeClassifier()
dt_cls.fit(X_train, y_train)
pred_dt_cls = dt_cls.predict(X_test)
print("Classification Report for Decision Tree Classifier:\n", classification_report(y_test, pred_dt_cls))
accuracy = accuracy_score(y_test, pred_dt_cls)
print("Accuracy score for Decision Tree Classifier: ", accuracy)
# Out:
# Classification Report for Decision Tree Classifier:
#                precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       589
#            1       0.30      0.39      0.34       137
#
#     accuracy                           0.72       726
#    macro avg       0.58      0.59      0.58       726
# weighted avg       0.75      0.72      0.73       726
#
# Accuracy score for Decision Tree Classifier:  0.7176308539944903

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)
pred_rf_cls = rf_classifier.predict(X_test)
print("Classification Report for Random Forest Classifier:\n", classification_report(y_test, pred_rf_cls))
accuracy = accuracy_score(y_test, pred_rf_cls)
print("Accuracy score for Random Forest Classifier: ", accuracy)
# Out:
# Classification Report for Random Forest Classifier:
#                precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89       589
#            1       0.52      0.16      0.25       137
#
#     accuracy                           0.81       726
#    macro avg       0.68      0.56      0.57       726
# weighted avg       0.77      0.81      0.77       726
#
# Accuracy score for Random Forest Classifier:  0.8140495867768595

# %%
lr_classifier = LogisticRegression()
lr_classifier.fit(X_train, y_train)
pred_lr_cls = lr_classifier.predict(X_test)
print("Classification Report for Logistic Regression Classifier:\n", classification_report(y_test, pred_lr_cls))
accuracy = accuracy_score(y_test, pred_lr_cls)
print("Accuracy score for Logistic Regression Classifier: ", accuracy)
# Out:
# Classification Report for Logistic Regression Classifier:
#                precision    recall  f1-score   support
#
#            0       0.82      0.99      0.90       592
#            1       0.50      0.02      0.04       135
#
#     accuracy                           0.81       727
#    macro avg       0.66      0.51      0.47       727
# weighted avg       0.76      0.81      0.74       727
#
# Accuracy score for Logistic Regression Classifier:  0.8143053645116919

# %% [markdown]
# ### Conclusion:
# #### Random Forest Classifier seems to perform best among all, as it has 83% accuracy
